# %%
import uproot
tree = uproot.open("opt0finder-art.flat.caf.root:recTree")

# %%
for key in tree.keys():
    if (("slc" in key) & ("self" in key)):
        print(key)
# Out:
# rec.slc.self

# %%
tree.arrays(["rec.slc.self",
             "rec.slc.opt0.hypoPE",
             "rec.slc.opt0.measPE",
             "rec.slc.opt0.score",
             "rec.slc.opt0.time",
             "rec.slc.opt0.tpc"],library="pd")
# Out:
#                 rec.slc.self  rec.slc.opt0.hypoPE  rec.slc.opt0.measPE  \
# entry subentry
# 0     0                   78         62142.414062            61.427502
#       1                   77         69281.648438         83388.468750
#       2                    0                  NaN                  NaN
#       3                    1                  NaN                  NaN
#       4                    3                  NaN                  NaN
#       5                    4                  NaN                  NaN
#       6                    5                  NaN                  NaN
#       7                    6                  NaN                  NaN
#       8                    8                  NaN                  NaN
#       9                    9                  NaN                  NaN
#       10                  10                  NaN                  NaN
#       11                  11                  NaN                  NaN
# ...
